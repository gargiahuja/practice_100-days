# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"F:\ML\100 days ml\practice\data\BreastCancer.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop(columns=['id','Unnamed: 32'],inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.decomposition import PCA
p=PCA()
p.fit(x_train_scaled)
plt.plot(range(1, x_train_scaled.shape[1]+1), p.explained_variance_ratio_.cumsum(), marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid()
plt.show()

# %%
x=df.iloc[:,1:]
y=df['diagnosis']

# %%
x.shape
# Out:
# (569, 30)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
p=PCA(n_components=7)
x_new_train=p.fit_transform(x_train_scaled)
x_new_test=p.transform(x_test_scaled)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
y_train_encoded=encoder.fit_transform(y_train)
y_test_encoded=encoder.transform(y_test)

# %%
x_new_test.shape
# Out:
# (114, 7)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
score=[]

# %%
print((y_test_encoded==0).sum())
print((y_test_encoded==1).sum())
# Out:
# 71
# 43

# %%
for i in range(1,100):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_new_train,y_train_encoded)
    print(accuracy_score(y_test_encoded,knn.predict(x_new_test)))
# Out:
# 0.9473684210526315
# 0.9385964912280702
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.956140350877193
# 0.9649122807017544
# 0.956140350877193
# 0.9649122807017544
# 0.9473684210526315
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.9473684210526315
# 0.9473684210526315
# 0.9473684210526315
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.9649122807017544
# 0.9649122807017544
# 0.9649122807017544
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test_encoded,knn.predict(x_new_test) ))
print(classification_report(y_test_encoded,knn.predict(x_new_test)))
# Out:
# [[69  2]
#  [ 2 41]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        71
#            1       0.95      0.95      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %%
knn=KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(x_new_train,y_train_encoded)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y=x.iloc[0,:]

# %%
x_new=pca.transform(y.values.reshape(1,-1))
x_new.shape
# Out:
# (1, 7)

# %%
x_new
# Out:
# array([[ 788.56897803, -786.30412639,   43.61553689, -116.53092443,
#          -34.05443715,  -52.3121943 ,   25.57515834,  243.07432853,
#         -421.63464452,  183.06204912,  475.51058257,  180.74218007,
#          -37.63515954,   31.43511786, -662.65294812, -406.39704434,
#         -327.52887243, -527.35710354,  651.02301107,   80.24485312,
#          320.43144847,   36.5807132 ,  434.91211132, -377.88901559,
#          151.73440093,  848.92416207, -714.39269002,   37.78037935,
#          499.31985146,   10.93383342]])

# %%
pca=PCA(n_components=7)

# %%
x_trainn=pca.fit_transform(x_train_scaled)
x_testt=pca.transform(x_test_scaled)

# %%
x_new=pca.transform(y.values.reshape(1,-1))
knn.predict(x_new)
# Out:
# array([1])

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...
