# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"F:\ML\100 days ml\data\train2.csv",usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.head(2)
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('GarageQual')
plt.ylabel('Number of houses')
# Out:
# Text(0, 0.5, 'Number of houses')

# %%
df.isnull().sum()
# Out:
# FireplaceQu    690
# GarageQual      81
# SalePrice        0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df["GarageQual"].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
df[df["GarageQual"]=="TA"]["SalePrice"].plot(kind="kde",ax=ax)
df[df["GarageQual"].isnull()]["SalePrice"].plot(kind="kde",ax=ax,color="red")
lines,labels=ax.get_legend_handles_labels()
labels=["Houses with TA","Houses with NA"]
ax.legend(lines,labels,loc="best")
plt.title("GarageQual")
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
temp=df[df["GarageQual"]=='TA']["SalePrice"]

# %%
df["GarageQual"].fillna("TA",inplace=True)

# %%
df["GarageQual"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
temp.plot(kind="kde",ax=ax)
df[df["GarageQual"]=="TA"]["SalePrice"].plot(kind="kde",ax=ax,color="red")
lines,labels=ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed variable']
ax.legend(lines, labels, loc='best')
plt.title('GarageQual')
# Out:
# Text(0.5, 1.0, 'GarageQual')

# %%
df["FireplaceQu"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df["FireplaceQu"].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=["SalePrice"]),df["SalePrice"],test_size=0.2,random_state=42)

# %%
from sklearn.impute import SimpleImputer
sim=SimpleImputer(strategy="most_frequent")
x_train=sim.fit_transform(x_train)
x_test=sim.transform(x_test)

# %%
sim.statistics_
# Out:
# array(['Gd', 'TA'], dtype=object)

# %%
df=pd.read_csv(r"F:\ML\100 days ml\data\train2.csv",usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df
# Out:
#      FireplaceQu GarageQual  SalePrice
# 0            NaN         TA     208500
# 1             TA         TA     181500
# 2             TA         TA     223500
# 3             Gd         TA     140000
# 4             TA         TA     250000
# ...          ...        ...        ...
# 1455          TA         TA     175000
# 1456          TA         TA     210000
# 1457          Gd         TA     266500
# 1458         NaN         TA     142125
# 1459         NaN         TA     147500
#
# [1460 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# FireplaceQu    690
# GarageQual      81
# SalePrice        0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
sim=SimpleImputer(strategy="constant",fill_value="Missing")

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop(columns=["SalePrice"]),df["SalePrice"],test_size=0.2,random_state=42)

# %%
x_train=sim.fit_transform(x_train)
x_test=sim.transform(x_test)
# Out:
# c:\Users\Gargi\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but SimpleImputer was fitted without feature names
#   warnings.warn(

# %%
sim.statistics_
# Out:
# array(['Missing', 'Missing'], dtype=object)
