# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv(r"F:\ML\100 days ml\ML practice\data\adult.csv")

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.shape
# Out:
# (48842, 15)

# %%
df['age'].unique()
# Out:
# array([25, 38, 28, 44, 18, 34, 29, 63, 24, 55, 65, 36, 26, 58, 48, 43, 20,
#        37, 40, 72, 45, 22, 23, 54, 32, 46, 56, 17, 39, 52, 21, 42, 33, 30,
#        47, 41, 19, 69, 50, 31, 59, 49, 51, 27, 57, 61, 64, 79, 73, 53, 77,
#        80, 62, 35, 68, 66, 75, 60, 67, 71, 70, 90, 81, 74, 78, 82, 83, 85,
#        76, 84, 89, 88, 87, 86], dtype=int64)

# %%
df['capital-gain'].unique()
# Out:
# array([    0,  7688,  3103,  6418,  7298,  3908, 14084,  5178, 15024,
#        99999,  2597,  2907,  4650,  6497,  1055,  5013, 27828,  4934,
#         4064,  3674,  2174, 10605,  3418,   114,  2580,  3411,  4508,
#         4386,  8614, 13550,  6849,  2463,  3137,  2885,  2964,  1471,
#        10566,  2354,  1424,  1455,  3325,  4416, 25236,   594,  2105,
#         4787,  2829,   401,  4865,  1264,  1506, 10520,  3464,  2653,
#        20051,  4101,  1797,  2407,  3471,  1086,  1848, 14344,  1151,
#         2993,  2290, 15020,  9386,  2202,  3818,  2176,  5455, 11678,
#         7978,  7262,  6514, 41310,  3456,  7430,  2414,  2062, 34095,
#         1831,  6723,  5060, 15831,  2977,  2346,  3273,  2329,  9562,
#         2635,  4931,  1731,  6097,   914,  7896,  5556,  1409,  3781,
#         3942,  2538,  3887, 25124,  7443,  5721,  1173,  4687,  6612,
#         6767,  2961,   991,  2036,  2936,  2050,  1111,  2228, 22040,
# ...

# %%
df['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df['income'].value_counts()
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
df[df['occupation']=='?'].shape
# Out:
# (2809, 15)

# %%
df['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df['income']=df['income'].map({'<=50K':0,'>50K':1})

# %%
df['income'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['income'].value_counts()
# Out:
# income
# 0    37155
# 1    11687
# Name: count, dtype: int64

# %%
df['age'].corr(df['income'])
# Out:
# 0.23036946784752074

# %%
df['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df.drop(columns=['fnlwgt','education'],inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'educational-num', 'marital-status', 'occupation',
#        'relationship', 'race', 'gender', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'native-country', 'income'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   educational-num  48842 non-null  int64
#  3   marital-status   48842 non-null  object
#  4   occupation       48842 non-null  object
#  5   relationship     48842 non-null  object
#  6   race             48842 non-null  object
#  7   gender           48842 non-null  object
#  8   capital-gain     48842 non-null  int64
#  9   capital-loss     48842 non-null  int64
#  10  hours-per-week   48842 non-null  int64
#  11  native-country   48842 non-null  object
#  12  income           48842 non-null  int64
# dtypes: int64(6), object(7)
# memory usage: 4.8+ MB

# %%
df['marital-status'].unique()
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Widowed', 'Divorced',
#        'Separated', 'Married-spouse-absent', 'Married-AF-spouse'],
#       dtype=object)

# %%
df['occupation'].unique()
# Out:
# array(['Machine-op-inspct', 'Farming-fishing', 'Protective-serv', '?',
#        'Other-service', 'Prof-specialty', 'Craft-repair', 'Adm-clerical',
#        'Exec-managerial', 'Tech-support', 'Sales', 'Priv-house-serv',
#        'Transport-moving', 'Handlers-cleaners', 'Armed-Forces'],
#       dtype=object)

# %%
df['occupation'][df['occupation']=='?']=np.nan
# Out:
# C:\Users\Gargi\AppData\Local\Temp\ipykernel_20784\1604097508.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['occupation'][df['occupation']=='?']=np.nan
# ...

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country        0
# income                0
# dtype: int64

# %%
df['relationship'].unique()
# Out:
# array(['Own-child', 'Husband', 'Not-in-family', 'Unmarried', 'Wife',
#        'Other-relative'], dtype=object)

# %%
df['race'].unique()
# Out:
# array(['Black', 'White', 'Asian-Pac-Islander', 'Other',
#        'Amer-Indian-Eskimo'], dtype=object)

# %%
df['native-country'].unique()
# Out:
# array(['United-States', '?', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican-Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El-Salvador', 'Puerto-Rico', 'Vietnam',
#        'South', 'Columbia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying-US(Guam-USVI-etc)', 'France',
#        'Holand-Netherlands'], dtype=object)

# %%
df['native-country'][df['native-country']=='?']=np.nan
# Out:
# C:\Users\Gargi\AppData\Local\Temp\ipykernel_20784\3948857152.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['native-country'][df['native-country']=='?']=np.nan
# ...

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.pairplot(df)

# %%
df['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df[df['workclass']=='?'].shape
# Out:
# (2799, 13)

# %%
df.loc[df['workclass'] == '?', 'workclass'] = np.nan

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
plt.pie(df['workclass'].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x25db784e9d0>,
# ...
#  [Text(-0.7438813462485716, 0.8103335996387, ''),
#   Text(0.1948224760653716, -1.0826099033445786, ''),
#   Text(0.6705427564217049, -0.8719933553705453, ''),
#   Text(0.9283880999411369, -0.589996216841842, ''),
#   Text(1.0457741431890206, -0.34111060000719684, ''),
#   Text(1.0942896749857511, -0.11193796147679083, ''),
#   Text(1.099995695497839, -0.0030773180247722015, ''),
#   Text(1.0999997438947922, -0.0007506206709695277, '')])

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df['educational-num'].unique()
# Out:
# array([ 7,  9, 12, 10,  6, 15,  4, 13, 14, 16,  3, 11,  5,  8,  2,  1],
#       dtype=int64)

# %%
df['educational-num'].value_counts()
# Out:
# educational-num
# 9     15784
# 10    10878
# 13     8025
# 14     2657
# 11     2061
# 7      1812
# 12     1601
# 6      1389
# 4       955
# 15      834
# 5       756
# 8       657
# 16      594
# 3       509
# 2       247
# 1        83
# Name: count, dtype: int64

# %%
df['capital-loss'].unique()
# Out:
# array([   0, 1721, 1876, 2415, 1887,  625, 1977, 2057, 1429, 1590, 1485,
#        2051, 2377, 1672, 1628, 1902, 1602, 1741, 2444, 1408, 2001, 2042,
#        1740, 1825, 1848, 1719, 3004, 2179, 1573, 2205, 1258, 2339, 1726,
#        2258, 1340, 1504, 2559, 1668, 1974, 1980, 1564, 2547, 2002, 1669,
#        1617,  323, 3175, 2472, 2174, 1579, 2129, 1510, 1735, 2282, 1870,
#        1411, 1911, 1651, 1092, 1762, 2457, 2231, 2238,  653, 1138, 2246,
#        2603, 2392, 1944, 1380, 2465, 1421, 3770, 1594,  213, 2149, 2824,
#        1844, 2467, 2163, 1816, 1648, 2206, 2352,  419, 1539,  880,  810,
#         974, 4356, 2489, 1755, 3683, 2267, 2080,  155, 3900, 2201, 2754],
#       dtype=int64)

# %%
df['hours-per-week'].unique()
# Out:
# array([40, 50, 30, 32, 10, 39, 35, 48, 25, 20, 45, 47,  6, 43, 90, 54, 60,
#        38, 36, 18, 24, 44, 56, 28, 16, 41, 22, 55, 14, 33, 37,  8, 12, 70,
#        15, 75, 52, 84, 42, 80, 68, 99, 65,  5, 17, 72, 53, 29, 96, 21, 46,
#         3,  1, 23, 49, 67, 76,  7,  2, 58, 26, 34,  4, 51, 78, 63, 31, 92,
#        77, 27, 85, 13, 19, 98, 62, 66, 57, 11, 86, 59,  9, 64, 73, 61, 88,
#        79, 89, 74, 69, 87, 97, 94, 82, 91, 81, 95], dtype=int64)

# %%
df['hours-per-week'].corr(df['income'])
# Out:
# 0.22768676056081072

# %%
from scipy.stats import pointbiserialr

r, p = pointbiserialr(df['income'], df['hours-per-week'])
print("Correlation coefficient:", r)
print("p-value:", p)
# Out:
# Correlation coefficient: 0.22768676056081538
# p-value: 0.0

# %%
sns.kdeplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
df['age'].mean()
# Out:
# 38.64358543876172

# %%
df.isnull().mean()*100
# Out:
# age                0.000000
# workclass          5.730724
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
df['native-country'].unique()
# Out:
# array(['United-States', nan, 'Peru', 'Guatemala', 'Mexico',
#        'Dominican-Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El-Salvador', 'Puerto-Rico', 'Vietnam',
#        'South', 'Columbia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying-US(Guam-USVI-etc)', 'France',
#        'Holand-Netherlands'], dtype=object)

# %%
df.groupby('income')['native-country'].value_counts()
# Out:
# income  native-country
# 0       United-States                 33138
#         Mexico                          904
#         Philippines                     210
#         Puerto-Rico                     164
#         Germany                         148
#                                       ...
# 1       Scotland                          3
#         Honduras                          2
#         Laos                              2
#         Trinadad&Tobago                   2
#         Outlying-US(Guam-USVI-etc)        1
# Name: count, Length: 81, dtype: int64

# %%
df['workclass'].isnull().sum()
# Out:
# 2799

# %%
sns.barplot(df['workclass'])
# Out:
# <Axes: ylabel='workclass'>

# %%
np.random.choice(df['workclass'],size=df['workclass'].isnull().sum())
# Out:
# array(['Private', 'Private', 'Self-emp-not-inc', ..., 'Private',
#        'Self-emp-inc', 'Private'], dtype=object)

# %%
mask=df['workclass'].isnull()

# %%
sns.barplot(x=df['workclass'],y=df['income'],data=df,estimator='mean')
# Out:
# <Axes: xlabel='workclass', ylabel='income'>

# %%
from scipy.stats import chi2_contingency
import pandas as pd

contingency = pd.crosstab(df['workclass'], df['income'])
chi2, p, dof, expected = chi2_contingency(contingency)
print(f"Chi-square = {chi2}")
print(f"p-value = {p}")
# Out:
# Chi-square = 1238.990039222109
# p-value = 2.6121798441462815e-263

# %%
df['educational-num'].corr(df['income'])
# Out:
# 0.3326131306661435

# %%
df['marital-status'].unique()
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Widowed', 'Divorced',
#        'Separated', 'Married-spouse-absent', 'Married-AF-spouse'],
#       dtype=object)

# %%
sns.barplot(x=df['marital-status'],y=df['income'],data=df,estimator='mean')
# Out:
# <Axes: xlabel='marital-status', ylabel='income'>

# %%
df['workclass'].isnull().sum()
# Out:
# 2799

# %%
df['workclass'][df['workclass'].isnull()]
df['workclass'].isnull().sum()
# Out:
# 2799

# %%
from sklearn.impute import SimpleImputer

# %%
df.loc[df['workclass'].isnull(), 'workclass'] = np.random.choice(
    df['workclass'].dropna(),
    size=df['workclass'].isnull().sum(),
    replace=True
)

# %%
df['race'].isnull().sum()
# Out:
# 0

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# ...

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# 1. Create contingency table
table = pd.crosstab(df['native-country'], df['income'])

# 2. Perform chi-square test
chi2, p, dof, expected = chi2_contingency(table)

print("Chi-square value:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
# Out:
# Chi-square value: 451.17601430219054
# p-value: 4.9465504983432925e-71
# Degrees of freedom: 40

# %%
import numpy as np

n = table.sum().sum()  # total observations
cramers_v = np.sqrt(chi2 / (n * (min(table.shape) - 1)))
print("Cramér’s V:", cramers_v)
# Out:
# Cramér’s V: 0.09696617224585236

# %%
df.drop(columns=['native-country'],inplace=True)

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# income                0
# dtype: int64

# %%
df['occupation'].unique()
# Out:
# array(['Machine-op-inspct', 'Farming-fishing', 'Protective-serv', nan,
#        'Other-service', 'Prof-specialty', 'Craft-repair', 'Adm-clerical',
#        'Exec-managerial', 'Tech-support', 'Sales', 'Priv-house-serv',
#        'Transport-moving', 'Handlers-cleaners', 'Armed-Forces'],
#       dtype=object)

# %%
sns.barplot(x=df['income'],y=df['occupation'],data=df,estimator='mean')
# Out:
# <Axes: xlabel='income', ylabel='occupation'>

# %%
df[df['occupation']=='Armed-Forces']['income'].value_counts()
# Out:
# income
# 0    10
# 1     5
# Name: count, dtype: int64

# %%
sns.displot(y=df['occupation'])

# %%
df['occupation'].unique()
# Out:
# array(['Machine-op-inspct', 'Farming-fishing', 'Protective-serv', nan,
#        'Other-service', 'Prof-specialty', 'Craft-repair', 'Adm-clerical',
#        'Exec-managerial', 'Tech-support', 'Sales', 'Priv-house-serv',
#        'Transport-moving', 'Handlers-cleaners', 'Armed-Forces'],
#       dtype=object)

# %%
df[df['occupation'].isnull()]
# Out:
#        age     workclass  educational-num      marital-status occupation  \
# 4       18     State-gov               10       Never-married        NaN
# 6       29       Private                9       Never-married        NaN
# 13      58       Private                9  Married-civ-spouse        NaN
# 22      72       Private                4            Divorced        NaN
# 35      65  Self-emp-inc                9  Married-civ-spouse        NaN
# ...    ...           ...              ...                 ...        ...
# 48811   35  Self-emp-inc               13  Married-civ-spouse        NaN
# 48812   30       Private               13       Never-married        NaN
# 48820   71       Private               16  Married-civ-spouse        NaN
# 48822   41       Private                9           Separated        NaN
# 48823   72       Private                9  Married-civ-spouse        NaN
#
#         relationship                race  gender  capital-gain  capital-loss  \
# ...

# %%
sns.countplot(y='workclass', hue=df['occupation'].isnull(), data=df)
# Out:
# <Axes: xlabel='count', ylabel='workclass'>

# %%
df['occupation']=df['occupation'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# income             0
# dtype: int64

# %%
df.head()
# Out:
#    age  workclass  educational-num      marital-status         occupation  \
# 0   25    Private                7       Never-married  Machine-op-inspct
# 1   38    Private                9  Married-civ-spouse    Farming-fishing
# 2   28  Local-gov               12  Married-civ-spouse    Protective-serv
# 3   44    Private               10  Married-civ-spouse  Machine-op-inspct
# 4   18  State-gov               10       Never-married            Unknown
#
#   relationship   race  gender  capital-gain  capital-loss  hours-per-week  \
# 0    Own-child  Black    Male             0             0              40
# 1      Husband  White    Male             0             0              50
# 2      Husband  White    Male             0             0              40
# 3      Husband  Black    Male          7688             0              40
# 4    Own-child  White  Female             0             0              30
#
#    income
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %%
df['income'].value_counts()/df['income'].shape
# Out:
# income
# 0    0.760718
# 1    0.239282
# Name: count, dtype: float64

# %%
df['income'].shape
# Out:
# (48842,)

# %%
df['income'].value_counts()/df['income'].shape*100
# Out:
# income
# 0    76.071823
# 1    23.928177
# Name: count, dtype: float64

# %%
df.shape
# Out:
# (48842, 12)

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# income             0
# dtype: int64

# %%
df.head()
# Out:
#    age  workclass  educational-num      marital-status         occupation  \
# 0   25    Private                7       Never-married  Machine-op-inspct
# 1   38    Private                9  Married-civ-spouse    Farming-fishing
# 2   28  Local-gov               12  Married-civ-spouse    Protective-serv
# 3   44    Private               10  Married-civ-spouse  Machine-op-inspct
# 4   18  State-gov               10       Never-married            Unknown
#
#   relationship   race  gender  capital-gain  capital-loss  hours-per-week  \
# 0    Own-child  Black    Male             0             0              40
# 1      Husband  White    Male             0             0              50
# 2      Husband  White    Male             0             0              40
# 3      Husband  Black    Male          7688             0              40
# 4    Own-child  White  Female             0             0              30
#
#    income
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %%
sns.kdeplot(df['capital-gain'])
# Out:
# <Axes: xlabel='capital-gain', ylabel='Density'>

# %%
df['capital-gain'].mean()
# Out:
# 1079.0676262233324

# %%
from scipy.stats import pointbiserialr

r, p = pointbiserialr(df['income'], df['capital-gain'])
print("Correlation coefficient:", r)
print("p-value:", p)
# Out:
# Correlation coefficient: 0.22301302085822902
# p-value: 0.0

# %%
import seaborn as sns
sns.boxplot(x='income', y='capital-loss', data=df)
# Out:
# <Axes: xlabel='income', ylabel='capital-loss'>

# %%
sns.boxplot(df['capital-gain'])
# Out:
# <Axes: ylabel='capital-gain'>

# %%
sns.kdeplot(df['capital-loss'])
# Out:
# <Axes: xlabel='capital-loss', ylabel='Density'>

# %%
df['capital-loss'].mode()
# Out:
# 0    0
# Name: capital-loss, dtype: int64

# %%
sns.boxplot(df['capital-loss'])
# Out:
# <Axes: ylabel='capital-loss'>

# %%
df['capital-gain'].value_counts()
# Out:
# capital-gain
# 0        44807
# 15024      513
# 7688       410
# 7298       364
# 99999      244
#          ...
# 1111         1
# 7262         1
# 22040        1
# 1639         1
# 2387         1
# Name: count, Length: 123, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['capital-gain'], bins=50, kde=True)
plt.xlim(0, 50000)
plt.show()

# %%
sns.kdeplot(df['capital-gain'])
# Out:
# <Axes: xlabel='capital-gain', ylabel='Density'>

# %%
df['capital-gain']=np.log1p(df['capital-gain'])

# %%
df['capital-gain']
# Out:
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        8.947546
# 4        0.000000
#            ...
# 48837    0.000000
# 48838    0.000000
# 48839    0.000000
# 48840    0.000000
# 48841    9.617471
# Name: capital-gain, Length: 48842, dtype: float64

# %%
df['capital-gain'].quantile(1)
# Out:
# 11.512925464970229

# %%
df['capital-gain'].corr(df['income'])
# Out:
# 0.289144153751467

# %%
df['capital-gain'].quantile(0.99)
# Out:
# 9.617470759403409

# %%
df['capital-gain-binary'] = df['capital-gain'].apply(lambda x: 1 if x > 0 else 0)

# %%
df['capital-loss'].value_counts()
# Out:
# capital-loss
# 0       46560
# 1902      304
# 1977      253
# 1887      233
# 2415       72
#         ...
# 2465        1
# 2080        1
# 155         1
# 1911        1
# 2201        1
# Name: count, Length: 99, dtype: int64

# %%
df['capital-loss-binary']=df['capital-loss'].apply(lambda x:1 if x>0 else 0)

# %%
sns.boxplot(df['capital-loss-binary'])
# Out:
# <Axes: ylabel='capital-loss-binary'>

# %%
sns.boxplot(df['capital-gain'])
# Out:
# <Axes: ylabel='capital-gain'>

# %%
df.head()
# Out:
#    age  workclass  educational-num      marital-status         occupation  \
# 0   25    Private                7       Never-married  Machine-op-inspct
# 1   38    Private                9  Married-civ-spouse    Farming-fishing
# 2   28  Local-gov               12  Married-civ-spouse    Protective-serv
# 3   44    Private               10  Married-civ-spouse  Machine-op-inspct
# 4   18  State-gov               10       Never-married            Unknown
#
#   relationship   race  gender  capital-gain  capital-loss  hours-per-week  \
# 0    Own-child  Black    Male      0.000000             0              40
# 1      Husband  White    Male      0.000000             0              50
# 2      Husband  White    Male      0.000000             0              40
# 3      Husband  Black    Male      8.947546             0              40
# 4    Own-child  White  Female      0.000000             0              30
#
#    income  capital-gain-binary  capital-loss-binary
# ...

# %%
from scipy.stats import pointbiserialr
r, p = pointbiserialr(df['income'], df['capital-gain-binary'])
print("r:", r, "p:", p)
# Out:
# r: 0.26591953665701246 p: 0.0

# %%
df.drop(columns=['capital-gain','capital-loss'],inplace=True)

# %%
df['gender']=df['gender'].map({'Male':1,'Female':0})

# %%
df['gender'].corr(df['income'])
# Out:
# 0.2146280345639281

# %%
df['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', 'State-gov', 'Self-emp-not-inc',
#        'Federal-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
sns.barplot(x=df['income'],y=df['workclass'])
# Out:
# <Axes: xlabel='income', ylabel='workclass'>

# %%
df.head()
# Out:
#    age  workclass  educational-num      marital-status         occupation  \
# 0   25    Private                7       Never-married  Machine-op-inspct
# 1   38    Private                9  Married-civ-spouse    Farming-fishing
# 2   28  Local-gov               12  Married-civ-spouse    Protective-serv
# 3   44    Private               10  Married-civ-spouse  Machine-op-inspct
# 4   18  State-gov               10       Never-married            Unknown
#
#   relationship   race  gender  hours-per-week  income  capital-gain-binary  \
# 0    Own-child  Black       1              40       0                    0
# 1      Husband  White       1              50       0                    0
# 2      Husband  White       1              40       1                    0
# 3      Husband  Black       1              40       1                    1
# 4    Own-child  White       0              30       0                    0
#
#    capital-loss-binary
# 0                    0
# ...

# %%
ct=pd.crosstab(df['income'],df['occupation'])
ct
# Out:
# occupation  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# income
# 0                   4843            10          4729             3178
# 1                    768             5          1383             2908
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# income
# 0                      1317               1934               2650
# 1                       173                138                372
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# income
# 0                    4719              239            3388              675
# 1                     204                3            2784              308
#
# occupation  Sales  Tech-support  Transport-moving  Unknown
# income
# 0            4029          1026              1874     2544
# 1            1475           420               481      265

# %%
gt=pd.crosstab(df['income'],df['educational-num'])

# %%
from scipy.stats import chi2_contingency
chi2,p, dof, expected=chi2_contingency(gt)
print(f"Chi-square value: {chi2}")
print(f"p-value: {p}")
print(f"Degrees of freedom: {dof}")
# Out:
# Chi-square value: 6537.972961360964
# p-value: 0.0
# Degrees of freedom: 15

# %%
import numpy as np

n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))
print(f"Cramér’s V: {cramers_v}")
# Out:
# Cramér’s V: 0.3658683488509228

# %%
occupation_target_mean = df.groupby('occupation')['income'].mean()
df['occupation_encoded'] = df['occupation'].map(occupation_target_mean)

# %%
df.head()
# Out:
#    age  workclass  educational-num      marital-status         occupation  \
# 0   25    Private                7       Never-married  Machine-op-inspct
# 1   38    Private                9  Married-civ-spouse    Farming-fishing
# 2   28  Local-gov               12  Married-civ-spouse    Protective-serv
# 3   44    Private               10  Married-civ-spouse  Machine-op-inspct
# 4   18  State-gov               10       Never-married            Unknown
#
#   relationship   race  gender  hours-per-week  income  capital-gain-binary  \
# 0    Own-child  Black       1              40       0                    0
# 1      Husband  White       1              50       0                    0
# 2      Husband  White       1              40       1                    0
# 3      Husband  Black       1              40       1                    1
# 4    Own-child  White       0              30       0                    0
#
#    capital-loss-binary  occupation_encoded
# ...

# %%
df['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', 'State-gov', 'Self-emp-not-inc',
#        'Federal-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df['workclass']=df['workclass'].map(df.groupby('workclass')['income'].mean())

# %%
df.head()
# Out:
#    age  workclass  educational-num      marital-status         occupation  \
# 0   25   0.210698                7       Never-married  Machine-op-inspct
# 1   38   0.210698                9  Married-civ-spouse    Farming-fishing
# 2   28   0.285887               12  Married-civ-spouse    Protective-serv
# 3   44   0.210698               10  Married-civ-spouse  Machine-op-inspct
# 4   18   0.260019               10       Never-married            Unknown
#
#   relationship   race  gender  hours-per-week  income  capital-gain-binary  \
# 0    Own-child  Black       1              40       0                    0
# 1      Husband  White       1              50       0                    0
# 2      Husband  White       1              40       1                    0
# 3      Husband  Black       1              40       1                    1
# 4    Own-child  White       0              30       0                    0
#
#    capital-loss-binary  occupation_encoded
# ...

# %%
df['workclass'].corr(df['income'])
# Out:
# 0.1562506679449225

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Unknown              2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    age  workclass  educational-num      marital-status         occupation  \
# 0   25   0.210698                7       Never-married  Machine-op-inspct
# 1   38   0.210698                9  Married-civ-spouse    Farming-fishing
# 2   28   0.285887               12  Married-civ-spouse    Protective-serv
# 3   44   0.210698               10  Married-civ-spouse  Machine-op-inspct
# 4   18   0.260019               10       Never-married            Unknown
#
#   relationship   race  gender  hours-per-week  income  capital-gain-binary  \
# 0    Own-child  Black       1              40       0                    0
# 1      Husband  White       1              50       0                    0
# 2      Husband  White       1              40       1                    0
# 3      Husband  Black       1              40       1                    1
# 4    Own-child  White       0              30       0                    0
#
#    capital-loss-binary  occupation_encoded
# ...

# %%
sns.barplot(df['occupation'])
# Out:
# <Axes: ylabel='occupation'>

# %%
import pandas as pd

ct = pd.crosstab(df['race'], df['income'])
print(ct)
# Out:
# income                  0      1
# race
# Amer-Indian-Eskimo    415     55
# Asian-Pac-Islander   1110    409
# Black                4119    566
# Other                 356     50
# White               31155  10607

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(ct)
print(f"Chi-square: {chi2}, p-value: {p}, dof: {dof}")
# Out:
# Chi-square: 487.026286837627, p-value: 4.2843777102235e-104, dof: 4

# %%
import numpy as np

n = ct.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(ct.shape)-1)))
print(f"Cramér’s V: {cramers_v}")
# Out:
# Cramér’s V: 0.09985722238766276

# %%
df.drop(columns=['race'],inplace=True)

# %%
df['income'].corr(df['hours-per-week'])
# Out:
# 0.2276867605608108

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
df['hours-per-week']=scale.fit_transform(df[['hours-per-week']])

# %%
df['hours-per-week'].std()
# Out:
# 1.000010237248228

# %%
sns.kdeplot(df['hours-per-week'])
# Out:
# <Axes: xlabel='hours-per-week', ylabel='Density'>

# %%
df['hours-per-week'].mean()
# Out:
# 4.4661688685629325e-17

# %%
df.head()
# Out:
#    age  workclass  educational-num      marital-status         occupation  \
# 0   25   0.210698                7       Never-married  Machine-op-inspct
# 1   38   0.210698                9  Married-civ-spouse    Farming-fishing
# 2   28   0.285887               12  Married-civ-spouse    Protective-serv
# 3   44   0.210698               10  Married-civ-spouse  Machine-op-inspct
# 4   18   0.260019               10       Never-married            Unknown
#
#   relationship  gender  hours-per-week  income  capital-gain-binary  \
# 0    Own-child       1       -0.034087       0                    0
# 1      Husband       1        0.772930       0                    0
# 2      Husband       1       -0.034087       1                    0
# 3      Husband       1       -0.034087       1                    1
# 4    Own-child       0       -0.841104       0                    0
#
#    capital-loss-binary  occupation_encoded
# 0                    0            0.123097
# ...

# %%
df['relationship'].value_counts()
# Out:
# relationship
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: count, dtype: int64

# %%
relation=pd.crosstab(df['income'],df['relationship'])
relation
# Out:
# relationship  Husband  Not-in-family  Other-relative  Own-child  Unmarried  \
# income
# 0               10870          11307            1454       7470       4816
# 1                8846           1276              52        111        309
#
# relationship  Wife
# income
# 0             1238
# 1             1093

# %%
from scipy.stats import chi2_contingency
ch2,p,dof,expected=chi2_contingency(relation)
print(f"Chi-square: {chi2}, p-value: {p}, dof: {dof}")
# Out:
# Chi-square: 487.026286837627, p-value: 0.0, dof: 5

# %%
import numpy as np

n = relation.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(relation.shape)-1)))
print(f"Cramér’s V: {cramers_v}")
# Out:
# Cramér’s V: 0.09985722238766276

# %%
df.drop(columns=['relationship'],inplace=True)

# %%
df.head()
# Out:
#    age  workclass  educational-num  marital-status         occupation  gender  \
# 0   25   0.210698                7        0.045480  Machine-op-inspct       1
# 1   38   0.210698                9        0.446133    Farming-fishing       1
# 2   28   0.285887               12        0.446133    Protective-serv       1
# 3   44   0.210698               10        0.446133  Machine-op-inspct       1
# 4   18   0.260019               10        0.045480            Unknown       0
#
#    hours-per-week  income  capital-gain-binary  capital-loss-binary  \
# 0       -0.034087       0                    0                    0
# 1        0.772930       0                    0                    0
# 2       -0.034087       1                    0                    0
# 3       -0.034087       1                    1                    0
# 4       -0.841104       0                    0                    0
#
#    occupation_encoded
# 0            0.123097
# 1            0.116107
# ...

# %%
df['marital-status'].unique()
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Widowed', 'Divorced',
#        'Separated', 'Married-spouse-absent', 'Married-AF-spouse'],
#       dtype=object)

# %%
co=pd.crosstab(df['income'],df['marital-status'])
co
# Out:
# marital-status  Divorced  Married-AF-spouse  Married-civ-spouse  \
# income
# 0                   5962                 23               12395
# 1                    671                 14                9984
#
# marital-status  Married-spouse-absent  Never-married  Separated  Widowed
# income
# 0                                 570          15384       1431     1390
# 1                                  58            733         99      128

# %%
from scipy.stats import chi2_contingency
import numpy as np

# Chi-square test
chi2, p, dof, expected = chi2_contingency(co)
print("Chi-square:", chi2)
print("p-value:", p)
print("dof:", dof)

# Cramér's V
n = co.sum().sum()
cramers_v = np.sqrt(chi2 / (n * (min(co.shape)-1)))
print("Cramér's V:", cramers_v)
# Out:
# Chi-square: 9816.015037266438
# p-value: 0.0
# dof: 6
# Cramér's V: 0.4483022183099439

# %%
df['marital-status'].corr(df['income'])
# Out:
# 0.44830221830994355

# %%
df['marital-status'].unique()
# Out:
# array([0.04547993, 0.44613253, 0.08432148, 0.10116086, 0.06470588,
#        0.09235669, 0.37837838])

# %%
df['marital-status']=df['marital-status'].map(df.groupby('marital-status')['income'].mean())

# %%
df.head()
# Out:
#         age  workclass  educational-num  marital-status  gender  \
# 0 -0.995129   0.210698                7        0.045480       1
# 1 -0.046942   0.210698                9        0.446133       1
# 2 -0.776316   0.285887               12        0.446133       1
# 3  0.390683   0.210698               10        0.446133       1
# 4 -1.505691   0.260019               10        0.045480       0
#
#    hours-per-week  capital-gain-binary  capital-loss-binary  \
# 0       -0.034087                    0                    0
# 1        0.772930                    0                    0
# 2       -0.034087                    0                    0
# 3       -0.034087                    1                    0
# 4       -0.841104                    0                    0
#
#    occupation_encoded  income
# 0            0.123097       0
# 1            0.116107       0
# 2            0.313327       1
# 3            0.123097       1
# 4            0.094340       0

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'educational-num', 'marital-status', 'gender',
#        'hours-per-week', 'income', 'capital-gain-binary',
#        'capital-loss-binary', 'occupation_encoded'],
#       dtype='object')

# %%
df=df[['age', 'workclass', 'educational-num', 'marital-status', 'gender',
       'hours-per-week', 'capital-gain-binary',
       'capital-loss-binary', 'occupation_encoded', 'income']]

# %%
df.drop(columns=['occupation'],inplace=True)

# %%
df['age']=scale.fit_transform(df[['age']])

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Unknown              2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df['age'].corr(df['income'])
# Out:
# 0.23036946784752074

# %%
df['hours-per-week'].quantile(1)
# Out:
# 4.727311617850181

# %%
Q1 = df['hours-per-week'].quantile(0.25)
Q3 = df['hours-per-week'].quantile(0.75)
IQR = Q3 - Q1

upper = Q3 + 1.5*IQR
lower = Q1 - 1.5*IQR

df_filtered = df[(df['hours-per-week'] <= upper) & (df['hours-per-week'] >= lower)]

# %%
sns.boxplot(df['hours-per-week'])
# Out:
# <Axes: ylabel='hours-per-week'>

# %%
sns.barplot(x=df['educational-num'],y=df['income'],estimator='mean')
# Out:
# <Axes: xlabel='educational-num', ylabel='income'>

# %%
df['educational-num'].value_counts()/df.shape[0]*100
# Out:
# educational-num
# 9     32.316449
# 10    22.271815
# 13    16.430531
# 14     5.439990
# 11     4.219729
# 7      3.709922
# 12     3.277917
# 6      2.843864
# 4      1.955284
# 15     1.707547
# 5      1.547848
# 8      1.345154
# 16     1.216166
# 3      1.042136
# 2      0.505712
# 1      0.169936
# Name: count, dtype: float64

# %%
sns.barplot(x=df['educational-num'].value_counts().index,
            y=(df['educational-num'].value_counts()/df.shape[0]*100).values)
plt.xlabel("Educational Number")
plt.ylabel("Percentage of People")
plt.title("Education Level Distribution")
plt.show()

# %%
df.shape
# Out:
# (48842, 12)

# %%
df['marital-status'].unique()
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Widowed', 'Divorced',
#        'Separated', 'Married-spouse-absent', 'Married-AF-spouse'],
#       dtype=object)

# %%
df.groupby('income')['marital-status'].value_counts()
# Out:
# income  marital-status
# 0       Never-married            15384
#         Married-civ-spouse       12395
#         Divorced                  5962
#         Separated                 1431
#         Widowed                   1390
#         Married-spouse-absent      570
#         Married-AF-spouse           23
# 1       Married-civ-spouse        9984
#         Never-married              733
#         Divorced                   671
#         Widowed                    128
#         Separated                   99
#         Married-spouse-absent       58
#         Married-AF-spouse           14
# Name: count, dtype: int64

# %%
sns.barplot(x=df['income'],y=df['marital-status'],estimator='mean')
# Out:
# <Axes: xlabel='income', ylabel='marital-status'>

# %%
sns.boxplot(x=df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
sns.kdeplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>
